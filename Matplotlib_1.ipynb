# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the Iris dataset
url = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
data = pd.read_csv(url)
data
# Display the first few rows of the dataset to get an overview
#print(data.head())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
x = np.linspace(0, 9, 100)
x
# Out:
# array([0.        , 0.09090909, 0.18181818, 0.27272727, 0.36363636,
#        0.45454545, 0.54545455, 0.63636364, 0.72727273, 0.81818182,
#        0.90909091, 1.        , 1.09090909, 1.18181818, 1.27272727,
#        1.36363636, 1.45454545, 1.54545455, 1.63636364, 1.72727273,
#        1.81818182, 1.90909091, 2.        , 2.09090909, 2.18181818,
#        2.27272727, 2.36363636, 2.45454545, 2.54545455, 2.63636364,
#        2.72727273, 2.81818182, 2.90909091, 3.        , 3.09090909,
#        3.18181818, 3.27272727, 3.36363636, 3.45454545, 3.54545455,
#        3.63636364, 3.72727273, 3.81818182, 3.90909091, 4.        ,
#        4.09090909, 4.18181818, 4.27272727, 4.36363636, 4.45454545,
#        4.54545455, 4.63636364, 4.72727273, 4.81818182, 4.90909091,
#        5.        , 5.09090909, 5.18181818, 5.27272727, 5.36363636,
#        5.45454545, 5.54545455, 5.63636364, 5.72727273, 5.81818182,
#        5.90909091, 6.        , 6.09090909, 6.18181818, 6.27272727,
# ...

# %%
y = np.sin(x)
y
# Out:
# array([ 0.        ,  0.09078392,  0.18081808,  0.26935891,  0.35567516,
#         0.43905397,  0.51880673,  0.59427479,  0.66483486,  0.72990422,
#         0.78894546,  0.84147098,  0.88704699,  0.92529707,  0.95590534,
#         0.978619  ,  0.99325047,  0.99967891,  0.99785123,  0.98778253,
#         0.96955595,  0.94332203,  0.90929743,  0.86776314,  0.8190622 ,
#         0.76359681,  0.70182505,  0.63425707,  0.56145091,  0.48400786,
#         0.40256749,  0.31780241,  0.23041267,  0.14112001,  0.05066187,
#        -0.04021468, -0.1307591 , -0.22022362, -0.30786935, -0.39297247,
#        -0.47483011, -0.55276624, -0.6261372 , -0.69433703, -0.7568025 ,
#        -0.8130177 , -0.86251837, -0.9048957 , -0.93979971, -0.96694212,
#        -0.98609877, -0.99711147, -0.99988924, -0.99440916, -0.98071647,
#        -0.95892427, -0.92921254, -0.89182665, -0.84707537, -0.79532828,
#        -0.73701276, -0.67261042, -0.60265314, -0.52771868, -0.44842592,
# ...

# %%
plt.plot(x, y)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Matplotlib Plot')

plt.show()

# %%
setosa_data = data[data['species'] == 'setosa']
setosa_data
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
x = setosa_data.index  
petal_length = setosa_data['petal_length']
petal_length
# Out:
# 0     1.4
# 1     1.4
# 2     1.3
# 3     1.5
# 4     1.4
# 5     1.7
# 6     1.4
# 7     1.5
# 8     1.4
# 9     1.5
# 10    1.5
# 11    1.6
# 12    1.4
# 13    1.1
# 14    1.2
# 15    1.5
# 16    1.3
# 17    1.4
# 18    1.7
# 19    1.5
# 20    1.7
# 21    1.5
# 22    1.0
# 23    1.7
# 24    1.9
# 25    1.6
# 26    1.6
# 27    1.5
# 28    1.4
# 29    1.6
# 30    1.6
# 31    1.5
# 32    1.5
# 33    1.4
# 34    1.5
# 35    1.2
# 36    1.3
# 37    1.5
# 38    1.3
# 39    1.5
# 40    1.3
# 41    1.3
# 42    1.3
# 43    1.6
# 44    1.9
# 45    1.4
# 46    1.6
# 47    1.4
# 48    1.5
# 49    1.4
# Name: petal_length, dtype: float64

# %%
plt.plot(x, petal_length, color='grey', linestyle='--', linewidth=1.5)
plt.xlabel('Data Points')
plt.ylabel('Petal Length (cm)')
plt.title('Petal Length of Setosa Iris')
# Out:
# Text(0.5, 1.0, 'Petal Length of Setosa Iris')

# %%
species= data['species']
species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
virginica_data = data[data['species'] == 'virginica']

print(setosa_data)
print(virginica_data)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
x = setosa_data.index  # Use the index as the x-axis values
sepal_length_setosa = setosa_data['sepal_length']
sepal_length_versicolor = virginica_data['sepal_length']
sepal_width_setosa = setosa_data['sepal_width']
sepal_width_versicolor = virginica_data['sepal_width']

# Create a line plot for sepal length
plt.plot(x, sepal_length_setosa, label='Setosa Sepal Length', color='lightblue', linestyle='-', linewidth=1.5)
plt.plot(x, sepal_length_versicolor, label='Virginica Sepal Length', color='lightgreen', linestyle='-', linewidth=1.5)

# Create a line plot for sepal width
plt.plot(x, sepal_width_setosa, label='Setosa Sepal Width', color='pink', linestyle='-', linewidth=1.5)
plt.plot(x, sepal_width_versicolor, label='Virginica Sepal Width', color='purple', linestyle='-', linewidth=1.5)

# Add labels and a title
plt.xlabel('Data Points')
plt.ylabel('Values (cm)')
plt.title('Sepal Length and Sepal Width Comparison')

# Add a legend to distinguish lines
plt.legend()

# Display the plot
plt.show()
